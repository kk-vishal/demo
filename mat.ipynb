# %% [markdown]
# <a href="https://colab.research.google.com/github/kk-vishal/demo/blob/main/mat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.4/485.4 kB 9.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 11.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 15.2 MB/s eta 0:00:00
# ...

# %%
from datasets import load_dataset
dataset = load_dataset('lukebarousse/data_jobs')
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# data_jobs.csv:   0%|          | 0.00/231M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/785741 [00:00<?, ? examples/s]

# %%
df = dataset['train'].to_pandas()

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df.dropna(subset = ['salary_year_avg'],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22003 entries, 28 to 785692
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        22003 non-null  object
#  1   job_title              22003 non-null  object
#  2   job_location           21723 non-null  object
#  3   job_via                22003 non-null  object
#  4   job_schedule_type      21987 non-null  object
#  5   job_work_from_home     22003 non-null  bool
#  6   search_location        22003 non-null  object
#  7   job_posted_date        22003 non-null  object
#  8   job_no_degree_mention  22003 non-null  bool
#  9   job_health_insurance   22003 non-null  bool
#  10  job_country            22003 non-null  object
#  11  salary_rate            22003 non-null  object
#  12  salary_year_avg        22003 non-null  float64
#  13  salary_hour_avg        0 non-null      float64
# ...

# %%
import pandas as pd
df['job_posted_date']=pd.to_datetime(df['job_posted_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22003 entries, 28 to 785692
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        22003 non-null  object
#  1   job_title              22003 non-null  object
#  2   job_location           21723 non-null  object
#  3   job_via                22003 non-null  object
#  4   job_schedule_type      21987 non-null  object
#  5   job_work_from_home     22003 non-null  bool
#  6   search_location        22003 non-null  object
#  7   job_posted_date        22003 non-null  datetime64[ns]
#  8   job_no_degree_mention  22003 non-null  bool
#  9   job_health_insurance   22003 non-null  bool
#  10  job_country            22003 non-null  object
#  11  salary_rate            22003 non-null  object
#  12  salary_year_avg        22003 non-null  float64
#  13  salary_hour_avg        0 non-null      float64
# ...

# %%
df['job_posted_month'] = df['job_posted_date'].dt.month

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22003 entries, 28 to 785692
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        22003 non-null  object
#  1   job_title              22003 non-null  object
#  2   job_location           21723 non-null  object
#  3   job_via                22003 non-null  object
#  4   job_schedule_type      21987 non-null  object
#  5   job_work_from_home     22003 non-null  bool
#  6   search_location        22003 non-null  object
#  7   job_posted_date        22003 non-null  datetime64[ns]
#  8   job_no_degree_mention  22003 non-null  bool
#  9   job_health_insurance   22003 non-null  bool
#  10  job_country            22003 non-null  object
#  11  salary_rate            22003 non-null  object
#  12  salary_year_avg        22003 non-null  float64
#  13  salary_hour_avg        0 non-null      float64
# ...

# %%
df.sort_values('job_posted_date', inplace = True)

# %%
df.describe()
# Out:
#                      job_posted_date  salary_year_avg  salary_hour_avg  job_posted_month
# count                          22003     22003.000000              0.0      22003.000000
# mean   2023-06-13 01:01:01.813889024    123286.274072              NaN          5.886288
# min              2023-01-01 00:02:56     15000.000000              NaN          1.000000
# 25%       2023-03-17 14:04:49.500000     90000.000000              NaN          3.000000
# 50%              2023-06-11 09:03:27    115000.000000              NaN          6.000000
# 75%              2023-08-26 00:41:15    150000.000000              NaN          8.000000
# max              2023-12-31 23:40:32    960000.000000              NaN         12.000000
# std                              NaN     48312.449482              NaN          3.296650

# %%
df['salary_year_avg'].mean()
# Out:
# 123286.27407182401

# %%
df['salary_year_avg'].median()
# Out:
# 115000.0

# %%
df['salary_year_avg'].min()
# Out:
# 15000.0

# %%
df.drop(labels = 'salary_hour_avg' , axis = 1 , inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22003 entries, 108883 to 327439
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        22003 non-null  object
#  1   job_title              22003 non-null  object
#  2   job_location           21723 non-null  object
#  3   job_via                22003 non-null  object
#  4   job_schedule_type      21987 non-null  object
#  5   job_work_from_home     22003 non-null  bool
#  6   search_location        22003 non-null  object
#  7   job_posted_date        22003 non-null  datetime64[ns]
#  8   job_no_degree_mention  22003 non-null  bool
#  9   job_health_insurance   22003 non-null  bool
#  10  job_country            22003 non-null  object
#  11  salary_rate            22003 non-null  object
#  12  salary_year_avg        22003 non-null  float64
#  13  company_name           22003 non-null  object
# ...

# %%
minimum= df['salary_year_avg'].idxmin()

# %%
df['job_title_short'].value_counts()
# Out:
# job_title_short
# Data Scientist               5922
# Data Analyst                 5451
# Data Engineer                4500
# Senior Data Scientist        1690
# Senior Data Engineer         1591
# Senior Data Analyst          1131
# Business Analyst              610
# Machine Learning Engineer     576
# Software Engineer             467
# Cloud Engineer                 65
# Name: count, dtype: int64

# %%
df['job_title_short'].unique()
# Out:
# array(['Data Scientist', 'Data Engineer', 'Business Analyst',
#        'Data Analyst', 'Senior Data Engineer', 'Senior Data Scientist',
#        'Senior Data Analyst', 'Software Engineer',
#        'Machine Learning Engineer', 'Cloud Engineer'], dtype=object)

# %%
df.groupby('job_title_short')['salary_year_avg'].mean()
# Out:
# job_title_short
# Business Analyst              91082.612833
# Cloud Engineer               111268.453846
# Data Analyst                  93841.907854
# Data Engineer                130125.604250
# Data Scientist               135988.837171
# Machine Learning Engineer    126774.315972
# Senior Data Analyst          113911.363665
# Senior Data Engineer         145840.611624
# Senior Data Scientist        154206.292996
# Software Engineer            113393.760054
# Name: salary_year_avg, dtype: float64

# %%
df.groupby(['job_title_short' , 'job_title'])['salary_year_avg'].mean()
# Out:
# job_title_short    job_title
# Business Analyst   (Senior) Security Operations Engineer, Singapore                      79200.0
#                    1403487 - Supply Chain Transformation Data & Analytics Project...     99800.0
#                    AML Operations Analyst                                                72825.0
#                    ASAALT - STRI Business Analyst (Orlando, FL)                         100000.0
#                    AU Core Assessment Analyst                                            55500.0
#                                                                                           ...
# Software Engineer  Technology Analyst Jobs                                              112500.0
#                    Technology analyst                                                    50000.0
#                    Thesis Cooperative collision avoidance for autonomous vehicles        56700.0
# ...

# %%
df.groupby('job_title_short')[['salary_year_avg' , 'job_posted_month']].min()
# Out:
#                            salary_year_avg  job_posted_month
# job_title_short
# Business Analyst                   16500.0                 1
# Cloud Engineer                     42000.0                 1
# Data Analyst                       25000.0                 1
# Data Engineer                      15000.0                 1
# Data Scientist                     27000.0                 1
# Machine Learning Engineer          30000.0                 1
# Senior Data Analyst                30000.0                 1
# Senior Data Engineer               35000.0                 1
# Senior Data Scientist              45000.0                 1
# Software Engineer                  28000.0                 1

# %%
df.groupby('job_title_short')[['salary_year_avg' , 'job_posted_month']].agg(['min','median','mean'])
# Out:
#                           salary_year_avg            ... job_posted_month
#                                       min    median  ...           median      mean
# job_title_short                                      ...
# Business Analyst                  16500.0   85000.0  ...              8.0  7.152459
# Cloud Engineer                    42000.0   90000.0  ...              6.0  5.830769
# Data Analyst                      25000.0   90000.0  ...              6.0  6.070262
# Data Engineer                     15000.0  125000.0  ...              5.0  5.670667
# Data Scientist                    27000.0  127500.0  ...              6.0  5.931949
# Machine Learning Engineer         30000.0  106415.0  ...              5.0  5.286458
# Senior Data Analyst               30000.0  111175.0  ...              6.0  5.678161
# Senior Data Engineer              35000.0  147500.0  ...              6.0  5.772470
# Senior Data Scientist             45000.0  155500.0  ...              6.0  5.618935
# ...

# %%
df['job_country'].head(20)
# Out:
# 108883    United States
# 334082        Argentina
# 365786    United States
# 366073    United States
# 108099    United States
# 78139     United States
# 710182      Switzerland
# 705374    United States
# 47131     United States
# 45205     United States
# 69156     United States
# 60095     United States
# 41270     United States
# 776813            Sudan
# 777985            Sudan
# 153859    United States
# 467812    United States
# 2862      United States
# 449502    United States
# 291092    United States
# Name: job_country, dtype: object

# %%
df['job_country'].isin(['Sudan'])
# Out:
# 108883    False
# 334082    False
# 365786    False
# 366073    False
# 108099    False
#           ...
# 186163    False
# 421728    False
# 313161    False
# 336301     True
# 327439     True
# Name: job_country, Length: 22003, dtype: bool

# %%
df['job_country'].isin(['Sudan']).any()
# Out:
# True

# %%
df['job_country'].isin(['Suda']).any()
# Out:
# False

# %%
us_jobs = df[df['job_country'] == 'United States']

# %%
us_jobs = us_jobs[us_jobs['salary_year_avg'].notna()]

# %%
us_jobs.groupby('job_title_short')['salary_year_avg'].agg(['min','max','median','count']).sort_values(by = 'median' , ascending =False)
# Out:
#                                min       max    median  count
# job_title_short
# Senior Data Scientist      55000.0  475000.0  155000.0   1241
# Machine Learning Engineer  44408.5  315000.0  150000.0    128
# Senior Data Engineer       45000.0  375000.0  150000.0   1058
# Data Scientist             30000.0  960000.0  130000.0   4553
# Software Engineer          48982.0  375000.0  130000.0    157
# Data Engineer              23496.0  525000.0  125000.0   2915
# Cloud Engineer             42000.0  221844.0  116100.0     20
# Senior Data Analyst        35360.0  425000.0  110000.0    913
# Business Analyst           35000.0  387460.0   90000.0    431
# Data Analyst               25000.0  375000.0   90000.0   4350

# %%
us_jobs.groupby('job_title_short').count()
# Out:
#                            job_title  job_location  job_via  \
# job_title_short
# Business Analyst                 431           425      431
# Cloud Engineer                    20            20       20
# Data Analyst                    4350          4285     4350
# Data Engineer                   2915          2869     2915
# Data Scientist                  4553          4498     4553
# Machine Learning Engineer        128           128      128
# Senior Data Analyst              913           903      913
# Senior Data Engineer            1058          1041     1058
# Senior Data Scientist           1241          1220     1241
# Software Engineer                157           155      157
#
#                            job_schedule_type  job_work_from_home  \
# job_title_short
# Business Analyst                         430                 431
# Cloud Engineer                            19                  20
# Data Analyst                            4342                4350
# ...

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- -------------------
# absl-py                            1.4.0
# accelerate                         1.3.0
# aiohappyeyeballs                   2.4.6
# aiohttp                            3.11.12
# aiosignal                          1.3.2
# alabaster                          1.0.0
# albucore                           0.0.23
# albumentations                     2.0.4
# ale-py                             0.10.2
# altair                             5.5.0
# annotated-types                    0.7.0
# anyio                              3.7.1
# argon2-cffi                        23.1.0
# argon2-cffi-bindings               21.2.0
# array_record                       0.6.0
# arviz                              0.20.0
# astropy                            7.0.1
# astropy-iers-data                  0.2025.2.17.0.34.13
# astunparse                         1.6.3
# atpublic                           4.1.0
# ...

# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(0, 5, 0.1)
y = np.sin(x)
plt.plot(x,y)

# %%
plt.plot(df['job_posted_date'],df['job_posted_date'])

# %%
date_count = df.job_posted_date.value_counts()

# %%
plt.plot(date_count.index , date_count)

# %%
month_count = df.job_posted_month.value_counts()

# %%
plt.plot(month_count.index , month_count.values)

# %%
job_count = df.job_title_short.value_counts().head(8)
job_count = job_count.sort_values(ascending  = True)

# %%
plt.plot(job_count.index , job_count.values)

# %%
plt.bar(job_count.index , job_count.values)
# Out:
# <BarContainer object of 8 artists>

# %%
plt.barh(job_count.index , job_count.values)
plt.title('Posting By Job Title')
plt.ylabel('Job Title')
plt.xlabel('Number Of Posting')
plt.xticks(rotation = 45)
plt.yticks(rotation = 45)
plt.show()
